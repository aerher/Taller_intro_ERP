# %% [markdown]
# # 06 Integración de Sistemas (ERP y SCM)
#
# En este ejercicio vamos a programar la lógica de negocio que permite a un sistema ERP integrar ventas con inventario y a un sistema SCM automatizar pedidos a proveedores.
#
# **Instrucciones:**
# 1. Leer el archivo de base de datos (`inventario_ERPSCM.csv`).
# 2. Completa las funciones en cada una de las celdas de las Partes 1, 2, y 3.
# 3. Ejecuta la celda de la **Parte 4** para probar si las funciones están correctas.
# 4. Repetir el paso 3. con más 3 productos diferentes.

# %%
import pandas as pd

# %%
# Usamos Pandas para una lectura limpia de los datos
base_datos_erp = pd.read_csv('inventario_ERPSCM.csv')
# Convertimos a lista de diccionarios para facilitar la iteración en este ejercicio
base_datos_erp = base_datos_erp.to_dict('records')
# Inicializamos la "Base de Datos" en memoria
ventas_totales_dia = 0.0

print(f" Datos cargados: {len(base_datos_erp)} productos en el sistema ERP.")
# Mostramos los datos usando Pandas para que se vea bonita la tabla
display(pd.DataFrame(base_datos_erp))
# Out:
#  Datos cargados: 302 productos en el sistema ERP.
#       id                                   nombre   precio  stock_actual  \
# 0    100        Laptop Gamer Muestra (Bajo Stock)  1500.00             2
# 1    101           Cable HDMI Básico (Stock Alto)    15.00           200
# 2    102  Audífonos Noise Cancelling Lenovo Gamer   306.71            79
# 3    103            Mouse Inalámbrico Xiaomi Slim    90.75            83
# 4    104                  Lavadora Apple Business   585.53            17
# ..   ...                                      ...      ...           ...
# 297  397                    Smartphone Lenovo Pro  1325.42            79
# 298  398            Parlante Bluetooth Xiaomi Pro   139.87            67
# 299  399                            Laptop HP Max  1927.56            71
# 300  400                            Laptop LG Pro  1284.85            41
# 301  401                        Monitor Canon Max   178.38            65
#
#      punto_reorden  pronostico_venta
# 0               10                25
# 1               20                50
# 2               26                88
# 3               23                86
# 4               26                23
# ..             ...               ...
# 297             22                80
# 298             30                71
# 299             26                68
# 300             18                48
# 301              5                80
#
# [302 rows x 6 columns]

# %% [markdown]
# ## Parte 1: Módulo ERP (Ventas e Inventario)
#
# Verifica si hay suficiente stock

# %%
def procesar_venta(id_producto, cantidad_deseada):
    global ventas_totales_dia
    producto_encontrado = False

    print(f"Se desea vender {cantidad_deseada} unidad(es) del producto {id_producto}...")

    for producto in base_datos_erp:
        if producto['id'] == id_producto:
            producto_encontrado = True

            # --- TAREA: Lógica ERP ---
            # Verifica si hay suficiente stock
            if producto['stock_actual'] >= cantidad_deseada: # <--- COMPLETA AQUÍ

                # Actualiza el stock
                producto['stock_actual'] = producto['stock_actual'] - cantidad_deseada # <--- COMPLETA AQUÍ

                # Calcula el ingreso (Precio * Cantidad)
                ingreso = producto['precio'] * cantidad_deseada # <--- COMPLETA AQUÍ
                ventas_totales_dia += ingreso

                print(f"   Transacción exitosa: {producto['nombre']}. Nuevo stock: {producto['stock_actual']}")
            else:
                print(f"   Error: Stock insuficiente para {producto['nombre']}.")

    if not producto_encontrado:
        print("   Error: Producto no encontrado.")

print("Módulo ERP cargado.")
# Out:
# Módulo ERP cargado.

# %% [markdown]
# ## Parte 2: Módulo SCM - Modelo PUSH
#
# Si el stock actual es menor al pronóstico, debemos comprar la diferencia

# %%
def ejecutar_modelo_push():
    print("\nEJECUTANDO MODELO SCM PUSH (MAKE-TO-STOCK)")
    print("Regla: Comprar anticipadamente si Stock Actual < Pronóstico.")

    compras_realizadas = 0

    for producto in base_datos_erp:
        stock = producto['stock_actual']
        pronostico = producto['pronostico_venta']

        # --- TAREA: Lógica Push ---
        # Si el stock actual es menor al pronóstico, debemos comprar la diferencia
        if stock < pronostico:

            # Calcula cuánto falta para alcanzar el pronóstico
            cantidad_a_comprar = pronostico - stock  # <--- COMPLETA AQUÍ

            print(f"   PUSH: {producto['nombre']} (Stock: {stock} | Pronóstico: {pronostico})")
            print(f"   Generando orden de compra por {cantidad_a_comprar} unidades.")

            # Simulamos llegada de mercadería
            producto['stock_actual'] += cantidad_a_comprar
            compras_realizadas += 1

    if compras_realizadas == 0:
        print("   PUSH Reporte: Inventario suficiente para los pronósticos.")

print("Módulo SCM (Push) cargado.")
# Out:
# Módulo SCM (Push) cargado.

# %% [markdown]
# ## Parte 3: Módulo SCM - Modelo PULL
#
# Si no hay stock, el modelo Pull dispara la compra

# %%
def ejecutar_modelo_pull(id_producto, cantidad_cliente):
    print(f"\n EJECUTANDO MODELO PULL (MAKE-TO-ORDER)")
    print(f"Cliente solicita {cantidad_cliente} unidades del producto {id_producto}...")

    for producto in base_datos_erp:
        if producto['id'] == id_producto:
            stock = producto['stock_actual']

            # --- TAREA 3: Lógica Pull ---
            if stock >= cantidad_cliente:
                print(f"    Stock suficiente ({stock}). Se despacha del inventario existente.")
                producto['stock_actual'] -= cantidad_cliente
            else:
                # Si no hay stock, el modelo Pull dispara la compra JUSTO AHORA
                faltante = cantidad_cliente - stock # <--- COMPLETA AQUÍ

                print(f"   Stock insuficiente. Faltan {faltante} unidades.")
                print(f"   -> PULL ACTIVADO: Comprando {faltante} unidades urgentemente...")

                print(f"    Pedido entregado al cliente (Just-in-Time).")
                # En Pull puro, el stock queda en 0 tras la entrega inmediata (si no se pidió extra)
                producto['stock_actual'] = 0

print("Módulo SCM (Pull) cargado.")
# Out:
# Módulo SCM (Pull) cargado.

# %% [markdown]
# ## Parte 4: Integración ERP - SCM
#
# Si no hay stock, el modelo Pull dispara la compra

# %%
# 1. Reiniciamos la base de datos para asegurar una prueba limpia
ventas_totales_dia = 0.0

print("--- 1. PROBANDO ERP (VENTAS) ---")
procesar_venta(101, 1)  # ¿Funciona o falla?
procesar_venta(103, 10) # ¿Funciona o falla?

# Se debe crear un caso en el que la venta funcione,
# y otro caso en el que la venta falle

print(f"\nDinero en Caja (Finanzas): ${ventas_totales_dia}")

print("\n--- 2. PROBANDO SCM (PUSH) ---")
# Esto debería reabastecer un producto que no se haya podido vender
ejecutar_modelo_push()

print("\n--- 3. PROBANDO SCM (PULL) ---")
# Se debe pedir un producto en una cantidad superior al stock
# El sistema Pull debería comprar los faltantes automáticamente
ejecutar_modelo_pull(105, 200)

print("\n📊 ESTADO FINAL DEL INVENTARIO (ERP INTEGRADO)")
# Convertimos de nuevo a DataFrame para ver la tabla bonita en Jupyter
display(pd.DataFrame(base_datos_erp))
# Out:
# --- 1. PROBANDO ERP (VENTAS) ---
# Se desea vender 1 unidad(es) del producto 101...
#    Transacción exitosa: Cable HDMI Básico (Stock Alto). Nuevo stock: 199
# Se desea vender 10 unidad(es) del producto 103...
#    Transacción exitosa: Mouse Inalámbrico Xiaomi Slim. Nuevo stock: 73
#
# Dinero en Caja (Finanzas): $922.5
#
# --- 2. PROBANDO SCM (PUSH) ---
#
# EJECUTANDO MODELO SCM PUSH (MAKE-TO-STOCK)
# Regla: Comprar anticipadamente si Stock Actual < Pronóstico.
#    PUSH: Laptop Gamer Muestra (Bajo Stock) (Stock: 2 | Pronóstico: 25)
#    Generando orden de compra por 23 unidades.
#    PUSH: Audífonos Noise Cancelling Lenovo Gamer (Stock: 79 | Pronóstico: 88)
#    Generando orden de compra por 9 unidades.
#    PUSH: Mouse Inalámbrico Xiaomi Slim (Stock: 73 | Pronóstico: 86)
#    Generando orden de compra por 13 unidades.
#    PUSH: Lavadora Apple Business (Stock: 17 | Pronóstico: 23)
#    Generando orden de compra por 6 unidades.
#    PUSH: Parlante Bluetooth Canon RGB (Stock: 2 | Pronóstico: 23)
#    Generando orden de compra por 21 unidades.
#    PUSH: Lavadora Dell Max (Stock: 3 | Pronóstico: 29)
#    Generando orden de compra por 26 unidades.
#    PUSH: Impresora Multifunción Canon Plus (Stock: 20 | Pronóstico: 38)
#    Generando orden de compra por 18 unidades.
#    PUSH: Parlante Bluetooth Xiaomi Gamer (Stock: 19 | Pronóstico: 31)
#    Generando orden de compra por 12 unidades.
#    PUSH: Monitor Lenovo Ultra (Stock: 16 | Pronóstico: 40)
#    Generando orden de compra por 24 unidades.
#    PUSH: Consola de Videojuegos LG Gamer (Stock: 37 | Pronóstico: 60)
#    Generando orden de compra por 23 unidades.
#    PUSH: Impresora Multifunción Epson Business (Stock: 7 | Pronóstico: 14)
#    Generando orden de compra por 7 unidades.
#    PUSH: Consola de Videojuegos Canon Max (Stock: 29 | Pronóstico: 53)
#    Generando orden de compra por 24 unidades.
#    PUSH: Mouse Inalámbrico Lenovo Plus (Stock: 50 | Pronóstico: 55)
#    Generando orden de compra por 5 unidades.
#    PUSH: Smartphone Apple Lite (Stock: 82 | Pronóstico: 106)
#    Generando orden de compra por 24 unidades.
#    PUSH: Lavadora Logitech Lite (Stock: 40 | Pronóstico: 51)
#    Generando orden de compra por 11 unidades.
#    PUSH: Cargador Rápido Apple Plus (Stock: 17 | Pronóstico: 46)
#    Generando orden de compra por 29 unidades.
#    PUSH: Router Wi-Fi 6 Xiaomi Home Edition (Stock: 88 | Pronóstico: 101)
#    Generando orden de compra por 13 unidades.
#    PUSH: Consola de Videojuegos Asus Pro (Stock: 70 | Pronóstico: 81)
#    Generando orden de compra por 11 unidades.
#    PUSH: Router Wi-Fi 6 Asus Slim (Stock: 60 | Pronóstico: 70)
#    Generando orden de compra por 10 unidades.
#    PUSH: Refrigeradora LG Lite (Stock: 75 | Pronóstico: 80)
#    Generando orden de compra por 5 unidades.
#    PUSH: Smart TV Lenovo Business (Stock: 26 | Pronóstico: 52)
#    Generando orden de compra por 26 unidades.
#    PUSH: Consola de Videojuegos Canon Slim (Stock: 14 | Pronóstico: 32)
#    Generando orden de compra por 18 unidades.
#    PUSH: Audífonos Noise Cancelling Canon 4K (Stock: 54 | Pronóstico: 60)
#    Generando orden de compra por 6 unidades.
#    PUSH: Cámara Reflex Xiaomi Business (Stock: 2 | Pronóstico: 28)
#    Generando orden de compra por 26 unidades.
#    PUSH: Tablet Dell Home Edition (Stock: 33 | Pronóstico: 48)
#    Generando orden de compra por 15 unidades.
#    PUSH: Smart TV Asus Max (Stock: 7 | Pronóstico: 26)
#    Generando orden de compra por 19 unidades.
#    PUSH: Cámara Reflex Microsoft Pro (Stock: 58 | Pronóstico: 70)
#    Generando orden de compra por 12 unidades.
#    PUSH: Tablet Sony Gamer (Stock: 18 | Pronóstico: 48)
#    Generando orden de compra por 30 unidades.
#    PUSH: Teclado Mecánico Asus Home Edition (Stock: 1 | Pronóstico: 2)
#    Generando orden de compra por 1 unidades.
#    PUSH: Disco Duro Externo HP RGB (Stock: 91 | Pronóstico: 103)
#    Generando orden de compra por 12 unidades.
#    PUSH: Smart TV Apple Slim (Stock: 70 | Pronóstico: 87)
#    Generando orden de compra por 17 unidades.
#    PUSH: Router Wi-Fi 6 Lenovo Pro (Stock: 7 | Pronóstico: 8)
#    Generando orden de compra por 1 unidades.
#    PUSH: Router Wi-Fi 6 Apple RGB (Stock: 23 | Pronóstico: 36)
#    Generando orden de compra por 13 unidades.
#    PUSH: Monitor Dell Lite (Stock: 83 | Pronóstico: 110)
#    Generando orden de compra por 27 unidades.
#    PUSH: Refrigeradora LG Plus (Stock: 5 | Pronóstico: 24)
#    Generando orden de compra por 19 unidades.
#    PUSH: Disco Duro Externo Samsung Slim (Stock: 68 | Pronóstico: 75)
#    Generando orden de compra por 7 unidades.
#    PUSH: Cargador Rápido HP Pro (Stock: 47 | Pronóstico: 59)
#    Generando orden de compra por 12 unidades.
#    PUSH: Mouse Inalámbrico Lenovo Pro (Stock: 51 | Pronóstico: 53)
#    Generando orden de compra por 2 unidades.
#    PUSH: Cable HDMI Microsoft Ultra (Stock: 73 | Pronóstico: 101)
#    Generando orden de compra por 28 unidades.
#    PUSH: Lavadora Apple Gamer (Stock: 12 | Pronóstico: 28)
#    Generando orden de compra por 16 unidades.
#    PUSH: Mouse Inalámbrico Dell Gamer (Stock: 42 | Pronóstico: 60)
#    Generando orden de compra por 18 unidades.
#    PUSH: Cargador Rápido Microsoft Max (Stock: 60 | Pronóstico: 85)
#    Generando orden de compra por 25 unidades.
#    PUSH: Impresora Multifunción Microsoft Gamer (Stock: 36 | Pronóstico: 62)
#    Generando orden de compra por 26 unidades.
#    PUSH: Smart TV Nintendo Home Edition (Stock: 91 | Pronóstico: 109)
#    Generando orden de compra por 18 unidades.
#    PUSH: Laptop Dell 4K (Stock: 12 | Pronóstico: 28)
#    Generando orden de compra por 16 unidades.
#    PUSH: Refrigeradora LG 4K (Stock: 30 | Pronóstico: 33)
#    Generando orden de compra por 3 unidades.
#    PUSH: Cable HDMI Apple Lite (Stock: 12 | Pronóstico: 33)
#    Generando orden de compra por 21 unidades.
#    PUSH: Consola de Videojuegos Samsung Plus (Stock: 51 | Pronóstico: 55)
#    Generando orden de compra por 4 unidades.
#    PUSH: Cámara Reflex Xiaomi Series X (Stock: 53 | Pronóstico: 55)
#    Generando orden de compra por 2 unidades.
#    PUSH: Lavadora Apple Ultra (Stock: 25 | Pronóstico: 32)
#    Generando orden de compra por 7 unidades.
#    PUSH: Cable HDMI Canon Slim (Stock: 88 | Pronóstico: 94)
#    Generando orden de compra por 6 unidades.
#    PUSH: Refrigeradora Apple Slim (Stock: 90 | Pronóstico: 91)
#    Generando orden de compra por 1 unidades.
#    PUSH: Cámara Reflex Dell Plus (Stock: 72 | Pronóstico: 85)
#    Generando orden de compra por 13 unidades.
#    PUSH: Parlante Bluetooth HP Pro (Stock: 98 | Pronóstico: 125)
#    Generando orden de compra por 27 unidades.
#    PUSH: Smart TV Microsoft Home Edition (Stock: 97 | Pronóstico: 100)
#    Generando orden de compra por 3 unidades.
#    PUSH: Cable HDMI Asus Home Edition (Stock: 23 | Pronóstico: 30)
#    Generando orden de compra por 7 unidades.
#    PUSH: Smartphone Microsoft Plus (Stock: 4 | Pronóstico: 22)
#    Generando orden de compra por 18 unidades.
#    PUSH: Lavadora Epson 4K (Stock: 7 | Pronóstico: 22)
#    Generando orden de compra por 15 unidades.
#    PUSH: Consola de Videojuegos Sony Series X (Stock: 83 | Pronóstico: 113)
#    Generando orden de compra por 30 unidades.
#    PUSH: Cámara Reflex Microsoft Plus (Stock: 33 | Pronóstico: 62)
#    Generando orden de compra por 29 unidades.
#    PUSH: Smartphone Canon Home Edition (Stock: 89 | Pronóstico: 115)
#    Generando orden de compra por 26 unidades.
#    PUSH: Audífonos Noise Cancelling Asus Slim (Stock: 0 | Pronóstico: 8)
#    Generando orden de compra por 8 unidades.
#    PUSH: Cargador Rápido Epson Ultra (Stock: 10 | Pronóstico: 36)
#    Generando orden de compra por 26 unidades.
#    PUSH: Refrigeradora Apple Gamer (Stock: 76 | Pronóstico: 100)
#    Generando orden de compra por 24 unidades.
#    PUSH: Disco Duro Externo HP Series X (Stock: 84 | Pronóstico: 102)
#    Generando orden de compra por 18 unidades.
#    PUSH: Cargador Rápido LG Slim (Stock: 93 | Pronóstico: 94)
#    Generando orden de compra por 1 unidades.
#    PUSH: Disco Duro Externo Lenovo 4K (Stock: 83 | Pronóstico: 111)
#    Generando orden de compra por 28 unidades.
#    PUSH: Cámara Reflex Canon Series X (Stock: 28 | Pronóstico: 41)
#    Generando orden de compra por 13 unidades.
#    PUSH: Smartphone Microsoft Max (Stock: 58 | Pronóstico: 76)
#    Generando orden de compra por 18 unidades.
#    PUSH: Lavadora Xiaomi Slim (Stock: 17 | Pronóstico: 37)
#    Generando orden de compra por 20 unidades.
#    PUSH: Cámara Reflex LG Home Edition (Stock: 82 | Pronóstico: 92)
#    Generando orden de compra por 10 unidades.
#    PUSH: Cargador Rápido Epson Ultra (Stock: 36 | Pronóstico: 66)
#    Generando orden de compra por 30 unidades.
#    PUSH: Consola de Videojuegos Dell RGB (Stock: 93 | Pronóstico: 110)
#    Generando orden de compra por 17 unidades.
#    PUSH: Lavadora Apple RGB (Stock: 21 | Pronóstico: 28)
#    Generando orden de compra por 7 unidades.
#    PUSH: Smartphone Samsung Gamer (Stock: 76 | Pronóstico: 90)
#    Generando orden de compra por 14 unidades.
#    PUSH: Audífonos Noise Cancelling Asus Home Edition (Stock: 34 | Pronóstico: 38)
#    Generando orden de compra por 4 unidades.
#    PUSH: Refrigeradora Sony Ultra (Stock: 10 | Pronóstico: 32)
#    Generando orden de compra por 22 unidades.
#    PUSH: Parlante Bluetooth Canon RGB (Stock: 11 | Pronóstico: 16)
#    Generando orden de compra por 5 unidades.
#    PUSH: Audífonos Noise Cancelling HP Max (Stock: 28 | Pronóstico: 40)
#    Generando orden de compra por 12 unidades.
#    PUSH: Parlante Bluetooth Canon Lite (Stock: 14 | Pronóstico: 36)
#    Generando orden de compra por 22 unidades.
#    PUSH: Disco Duro Externo HP Series X (Stock: 94 | Pronóstico: 96)
#    Generando orden de compra por 2 unidades.
#    PUSH: Tablet Canon Ultra (Stock: 67 | Pronóstico: 76)
#    Generando orden de compra por 9 unidades.
#    PUSH: Smart TV Apple 4K (Stock: 85 | Pronóstico: 101)
#    Generando orden de compra por 16 unidades.
#    PUSH: Parlante Bluetooth Dell Pro (Stock: 35 | Pronóstico: 37)
#    Generando orden de compra por 2 unidades.
#    PUSH: Cámara Reflex Lenovo Ultra (Stock: 64 | Pronóstico: 74)
#    Generando orden de compra por 10 unidades.
#    PUSH: Laptop Canon Plus (Stock: 11 | Pronóstico: 36)
#    Generando orden de compra por 25 unidades.
#    PUSH: Lavadora Sony Ultra (Stock: 35 | Pronóstico: 39)
#    Generando orden de compra por 4 unidades.
#    PUSH: Smart TV Sony Ultra (Stock: 5 | Pronóstico: 32)
#    Generando orden de compra por 27 unidades.
#    PUSH: Cámara Reflex Xiaomi Home Edition (Stock: 1 | Pronóstico: 14)
#    Generando orden de compra por 13 unidades.
#    PUSH: Lavadora Samsung Max (Stock: 47 | Pronóstico: 53)
#    Generando orden de compra por 6 unidades.
#    PUSH: Audífonos Noise Cancelling Asus Lite (Stock: 7 | Pronóstico: 11)
#    Generando orden de compra por 4 unidades.
#    PUSH: Cargador Rápido LG RGB (Stock: 13 | Pronóstico: 36)
#    Generando orden de compra por 23 unidades.
#    PUSH: Lavadora Xiaomi Business (Stock: 22 | Pronóstico: 24)
#    Generando orden de compra por 2 unidades.
#    PUSH: Laptop Microsoft Gamer (Stock: 55 | Pronóstico: 70)
#    Generando orden de compra por 15 unidades.
#    PUSH: Cable HDMI Lenovo RGB (Stock: 1 | Pronóstico: 2)
#    Generando orden de compra por 1 unidades.
#    PUSH: Impresora Multifunción Lenovo 4K (Stock: 4 | Pronóstico: 12)
#    Generando orden de compra por 8 unidades.
#    PUSH: Smart TV Dell 4K (Stock: 46 | Pronóstico: 75)
#    Generando orden de compra por 29 unidades.
#    PUSH: Smartphone Epson 4K (Stock: 93 | Pronóstico: 104)
#    Generando orden de compra por 11 unidades.
#    PUSH: Tablet Xiaomi Max (Stock: 51 | Pronóstico: 57)
#    Generando orden de compra por 6 unidades.
#    PUSH: Smartphone Epson Series X (Stock: 47 | Pronóstico: 54)
#    Generando orden de compra por 7 unidades.
#    PUSH: Consola de Videojuegos Samsung Ultra (Stock: 25 | Pronóstico: 46)
#    Generando orden de compra por 21 unidades.
#    PUSH: Parlante Bluetooth Lenovo Gamer (Stock: 16 | Pronóstico: 31)
#    Generando orden de compra por 15 unidades.
#    PUSH: Monitor Canon Lite (Stock: 84 | Pronóstico: 102)
#    Generando orden de compra por 18 unidades.
#    PUSH: Monitor Xiaomi Lite (Stock: 50 | Pronóstico: 72)
#    Generando orden de compra por 22 unidades.
#    PUSH: Cargador Rápido Nintendo RGB (Stock: 56 | Pronóstico: 69)
#    Generando orden de compra por 13 unidades.
#    PUSH: Smartphone Lenovo 4K (Stock: 1 | Pronóstico: 15)
#    Generando orden de compra por 14 unidades.
#    PUSH: Disco Duro Externo HP Gamer (Stock: 95 | Pronóstico: 116)
#    Generando orden de compra por 21 unidades.
#    PUSH: Disco Duro Externo Lenovo Gamer (Stock: 79 | Pronóstico: 82)
#    Generando orden de compra por 3 unidades.
#    PUSH: Monitor Epson 4K (Stock: 81 | Pronóstico: 87)
#    Generando orden de compra por 6 unidades.
#    PUSH: Consola de Videojuegos Xiaomi Max (Stock: 35 | Pronóstico: 40)
#    Generando orden de compra por 5 unidades.
#    PUSH: Monitor Xiaomi Pro (Stock: 39 | Pronóstico: 59)
#    Generando orden de compra por 20 unidades.
#    PUSH: Mouse Inalámbrico Samsung Slim (Stock: 69 | Pronóstico: 73)
#    Generando orden de compra por 4 unidades.
#    PUSH: Smartphone Dell Plus (Stock: 40 | Pronóstico: 56)
#    Generando orden de compra por 16 unidades.
#    PUSH: Parlante Bluetooth Epson Max (Stock: 12 | Pronóstico: 34)
#    Generando orden de compra por 22 unidades.
#    PUSH: Impresora Multifunción Asus Plus (Stock: 20 | Pronóstico: 47)
#    Generando orden de compra por 27 unidades.
#    PUSH: Impresora Multifunción Nintendo RGB (Stock: 2 | Pronóstico: 15)
#    Generando orden de compra por 13 unidades.
#    PUSH: Laptop Microsoft Plus (Stock: 93 | Pronóstico: 117)
#    Generando orden de compra por 24 unidades.
#    PUSH: Disco Duro Externo Asus Business (Stock: 49 | Pronóstico: 62)
#    Generando orden de compra por 13 unidades.
#    PUSH: Impresora Multifunción Asus RGB (Stock: 87 | Pronóstico: 116)
#    Generando orden de compra por 29 unidades.
#    PUSH: Smart TV Lenovo Business (Stock: 9 | Pronóstico: 39)
#    Generando orden de compra por 30 unidades.
#    PUSH: Teclado Mecánico Xiaomi RGB (Stock: 39 | Pronóstico: 45)
#    Generando orden de compra por 6 unidades.
#    PUSH: Audífonos Noise Cancelling Dell RGB (Stock: 76 | Pronóstico: 82)
#    Generando orden de compra por 6 unidades.
#    PUSH: Smart TV Sony Max (Stock: 86 | Pronóstico: 90)
#    Generando orden de compra por 4 unidades.
#    PUSH: Mouse Inalámbrico Lenovo Plus (Stock: 48 | Pronóstico: 70)
#    Generando orden de compra por 22 unidades.
#    PUSH: Impresora Multifunción Epson Series X (Stock: 8 | Pronóstico: 19)
#    Generando orden de compra por 11 unidades.
#    PUSH: Monitor Asus Pro (Stock: 22 | Pronóstico: 39)
#    Generando orden de compra por 17 unidades.
#    PUSH: Mouse Inalámbrico LG Gamer (Stock: 80 | Pronóstico: 97)
#    Generando orden de compra por 17 unidades.
#    PUSH: Cámara Reflex Lenovo Lite (Stock: 19 | Pronóstico: 27)
#    Generando orden de compra por 8 unidades.
#    PUSH: Refrigeradora Nintendo 4K (Stock: 8 | Pronóstico: 14)
#    Generando orden de compra por 6 unidades.
#    PUSH: Laptop Apple Lite (Stock: 39 | Pronóstico: 58)
#    Generando orden de compra por 19 unidades.
#    PUSH: Router Wi-Fi 6 Nintendo Plus (Stock: 15 | Pronóstico: 39)
#    Generando orden de compra por 24 unidades.
#    PUSH: Smartphone Apple Slim (Stock: 70 | Pronóstico: 93)
#    Generando orden de compra por 23 unidades.
#    PUSH: Disco Duro Externo HP Max (Stock: 76 | Pronóstico: 83)
#    Generando orden de compra por 7 unidades.
#    PUSH: Disco Duro Externo Nintendo Ultra (Stock: 14 | Pronóstico: 39)
#    Generando orden de compra por 25 unidades.
#    PUSH: Consola de Videojuegos Microsoft Plus (Stock: 47 | Pronóstico: 57)
#    Generando orden de compra por 10 unidades.
#    PUSH: Teclado Mecánico Asus Lite (Stock: 66 | Pronóstico: 81)
#    Generando orden de compra por 15 unidades.
#    PUSH: Cámara Reflex LG Max (Stock: 90 | Pronóstico: 118)
#    Generando orden de compra por 28 unidades.
#    PUSH: Teclado Mecánico Asus Gamer (Stock: 23 | Pronóstico: 52)
#    Generando orden de compra por 29 unidades.
#    PUSH: Monitor Logitech Max (Stock: 99 | Pronóstico: 104)
#    Generando orden de compra por 5 unidades.
#    PUSH: Monitor Lenovo Slim (Stock: 45 | Pronóstico: 65)
#    Generando orden de compra por 20 unidades.
#    PUSH: Impresora Multifunción Logitech Max (Stock: 88 | Pronóstico: 103)
#    Generando orden de compra por 15 unidades.
#    PUSH: Parlante Bluetooth Microsoft Series X (Stock: 61 | Pronóstico: 69)
#    Generando orden de compra por 8 unidades.
#    PUSH: Laptop Apple Home Edition (Stock: 52 | Pronóstico: 74)
#    Generando orden de compra por 22 unidades.
#    PUSH: Disco Duro Externo Lenovo Pro (Stock: 27 | Pronóstico: 34)
#    Generando orden de compra por 7 unidades.
#    PUSH: Cargador Rápido Asus Series X (Stock: 9 | Pronóstico: 38)
#    Generando orden de compra por 29 unidades.
#    PUSH: Smartphone Asus Home Edition (Stock: 53 | Pronóstico: 62)
#    Generando orden de compra por 9 unidades.
#    PUSH: Cable HDMI Apple Plus (Stock: 79 | Pronóstico: 97)
#    Generando orden de compra por 18 unidades.
#    PUSH: Tablet Dell Plus (Stock: 87 | Pronóstico: 113)
#    Generando orden de compra por 26 unidades.
#    PUSH: Cargador Rápido Microsoft RGB (Stock: 63 | Pronóstico: 76)
#    Generando orden de compra por 13 unidades.
#    PUSH: Disco Duro Externo Xiaomi Plus (Stock: 27 | Pronóstico: 44)
#    Generando orden de compra por 17 unidades.
#    PUSH: Router Wi-Fi 6 Canon RGB (Stock: 55 | Pronóstico: 61)
#    Generando orden de compra por 6 unidades.
#    PUSH: Cámara Reflex Xiaomi Plus (Stock: 34 | Pronóstico: 46)
#    Generando orden de compra por 12 unidades.
#    PUSH: Disco Duro Externo Canon Max (Stock: 41 | Pronóstico: 53)
#    Generando orden de compra por 12 unidades.
#    PUSH: Laptop Lenovo Gamer (Stock: 70 | Pronóstico: 94)
#    Generando orden de compra por 24 unidades.
#    PUSH: Cargador Rápido Epson Max (Stock: 83 | Pronóstico: 93)
#    Generando orden de compra por 10 unidades.
#    PUSH: Refrigeradora Nintendo Business (Stock: 99 | Pronóstico: 103)
#    Generando orden de compra por 4 unidades.
#    PUSH: Cargador Rápido Logitech Ultra (Stock: 83 | Pronóstico: 110)
#    Generando orden de compra por 27 unidades.
#    PUSH: Tablet Dell Series X (Stock: 46 | Pronóstico: 47)
#    Generando orden de compra por 1 unidades.
#    PUSH: Mouse Inalámbrico HP 4K (Stock: 25 | Pronóstico: 42)
#    Generando orden de compra por 17 unidades.
#    PUSH: Cable HDMI Microsoft Ultra (Stock: 70 | Pronóstico: 88)
#    Generando orden de compra por 18 unidades.
#    PUSH: Smartphone LG Gamer (Stock: 8 | Pronóstico: 33)
#    Generando orden de compra por 25 unidades.
#    PUSH: Parlante Bluetooth Microsoft Gamer (Stock: 39 | Pronóstico: 65)
#    Generando orden de compra por 26 unidades.
#    PUSH: Parlante Bluetooth Microsoft Plus (Stock: 8 | Pronóstico: 35)
#    Generando orden de compra por 27 unidades.
#    PUSH: Cable HDMI Nintendo Plus (Stock: 83 | Pronóstico: 91)
#    Generando orden de compra por 8 unidades.
#    PUSH: Disco Duro Externo Asus Max (Stock: 45 | Pronóstico: 72)
#    Generando orden de compra por 27 unidades.
#    PUSH: Router Wi-Fi 6 Sony Pro (Stock: 24 | Pronóstico: 29)
#    Generando orden de compra por 5 unidades.
#    PUSH: Laptop HP Max (Stock: 86 | Pronóstico: 102)
#    Generando orden de compra por 16 unidades.
#    PUSH: Router Wi-Fi 6 Asus Pro (Stock: 24 | Pronóstico: 34)
#    Generando orden de compra por 10 unidades.
#    PUSH: Disco Duro Externo Xiaomi Home Edition (Stock: 81 | Pronóstico: 96)
#    Generando orden de compra por 15 unidades.
#    PUSH: Disco Duro Externo Asus Lite (Stock: 48 | Pronóstico: 75)
#    Generando orden de compra por 27 unidades.
#    PUSH: Consola de Videojuegos Epson 4K (Stock: 81 | Pronóstico: 87)
#    Generando orden de compra por 6 unidades.
#    PUSH: Parlante Bluetooth LG Plus (Stock: 10 | Pronóstico: 34)
#    Generando orden de compra por 24 unidades.
#    PUSH: Cargador Rápido Canon Gamer (Stock: 0 | Pronóstico: 27)
#    Generando orden de compra por 27 unidades.
#    PUSH: Cargador Rápido LG 4K (Stock: 79 | Pronóstico: 95)
#    Generando orden de compra por 16 unidades.
#    PUSH: Lavadora LG Ultra (Stock: 33 | Pronóstico: 49)
#    Generando orden de compra por 16 unidades.
#    PUSH: Monitor Asus Pro (Stock: 84 | Pronóstico: 95)
#    Generando orden de compra por 11 unidades.
#    PUSH: Smartphone Lenovo Pro (Stock: 79 | Pronóstico: 80)
#    Generando orden de compra por 1 unidades.
#    PUSH: Parlante Bluetooth Xiaomi Pro (Stock: 67 | Pronóstico: 71)
#    Generando orden de compra por 4 unidades.
#    PUSH: Laptop LG Pro (Stock: 41 | Pronóstico: 48)
#    Generando orden de compra por 7 unidades.
#    PUSH: Monitor Canon Max (Stock: 65 | Pronóstico: 80)
#    Generando orden de compra por 15 unidades.
#
# --- 3. PROBANDO SCM (PULL) ---
#
#  EJECUTANDO MODELO PULL (MAKE-TO-ORDER)
# Cliente solicita 200 unidades del producto 105...
#    Stock insuficiente. Faltan 177 unidades.
#    -> PULL ACTIVADO: Comprando 177 unidades urgentemente...
#     Pedido entregado al cliente (Just-in-Time).
#
# 📊 ESTADO FINAL DEL INVENTARIO (ERP INTEGRADO)
#       id                                   nombre   precio  stock_actual  \
# 0    100        Laptop Gamer Muestra (Bajo Stock)  1500.00            25
# 1    101           Cable HDMI Básico (Stock Alto)    15.00           199
# 2    102  Audífonos Noise Cancelling Lenovo Gamer   306.71            88
# 3    103            Mouse Inalámbrico Xiaomi Slim    90.75            86
# 4    104                  Lavadora Apple Business   585.53            23
# ..   ...                                      ...      ...           ...
# 297  397                    Smartphone Lenovo Pro  1325.42            80
# 298  398            Parlante Bluetooth Xiaomi Pro   139.87            71
# 299  399                            Laptop HP Max  1927.56            71
# 300  400                            Laptop LG Pro  1284.85            48
# 301  401                        Monitor Canon Max   178.38            80
#
#      punto_reorden  pronostico_venta
# 0               10                25
# 1               20                50
# 2               26                88
# 3               23                86
# 4               26                23
# ..             ...               ...
# 297             22                80
# 298             30                71
# 299             26                68
# 300             18                48
# 301              5                80
#
# [302 rows x 6 columns]

# %% [markdown]
# ## Parte 5 : Probando Ventas

# %%
print("--- 5. PROBANDO ERP (VENTAS) ---")

procesar_venta(115, 10)

procesar_venta(102, 8)

procesar_venta(192, 7)

procesar_venta(209, 2)

procesar_venta( 189, 15)

print(f"\nDinero en Caja (Finanzas): ${ventas_totales_dia}")


print("\n--- 2. PROBANDO SCM (PUSH) ---")
# Esto debería reabastecer un producto que no se haya podido vender
ejecutar_modelo_push()

print("\n--- 3. PROBANDO SCM (PULL) ---")
# Se debe pedir un producto en una cantidad superior al stock
# El sistema Pull debería comprar los faltantes automáticamente
ejecutar_modelo_pull(105, 200)

print("\n📊 ESTADO FINAL DEL INVENTARIO (ERP INTEGRADO)")
# Convertimos de nuevo a DataFrame para ver la tabla bonita en Jupyter
display(pd.DataFrame(base_datos_erp))
# Out:
# --- 5. PROBANDO ERP (VENTAS) ---
# Se desea vender 10 unidad(es) del producto 115...
#    Error: Stock insuficiente para Monitor Lenovo Ultra.
# Se desea vender 8 unidad(es) del producto 102...
#    Transacción exitosa: Audífonos Noise Cancelling Lenovo Gamer. Nuevo stock: 48
# Se desea vender 7 unidad(es) del producto 192...
#    Error: Stock insuficiente para Consola de Videojuegos Apple Series X.
# Se desea vender 2 unidad(es) del producto 209...
#    Transacción exitosa: Disco Duro Externo HP Series X. Nuevo stock: 96
# Se desea vender 15 unidad(es) del producto 189...
#    Transacción exitosa: Smart TV Microsoft Home Edition. Nuevo stock: 55
#
# Dinero en Caja (Finanzas): $99871.54999999999
#
# --- 2. PROBANDO SCM (PUSH) ---
#
# EJECUTANDO MODELO SCM PUSH (MAKE-TO-STOCK)
# Regla: Comprar anticipadamente si Stock Actual < Pronóstico.
#    PUSH: Audífonos Noise Cancelling Lenovo Gamer (Stock: 48 | Pronóstico: 88)
#    Generando orden de compra por 40 unidades.
#    PUSH: Parlante Bluetooth Canon RGB (Stock: 0 | Pronóstico: 23)
#    Generando orden de compra por 23 unidades.
#    PUSH: Monitor Lenovo Ultra (Stock: 0 | Pronóstico: 40)
#    Generando orden de compra por 40 unidades.
#    PUSH: Smart TV Microsoft Home Edition (Stock: 55 | Pronóstico: 100)
#    Generando orden de compra por 45 unidades.
#    PUSH: Consola de Videojuegos Apple Series X (Stock: 4 | Pronóstico: 5)
#    Generando orden de compra por 1 unidades.
#    PUSH: Disco Duro Externo HP Series X (Stock: 96 | Pronóstico: 102)
#    Generando orden de compra por 6 unidades.
#
# --- 3. PROBANDO SCM (PULL) ---
#
#  EJECUTANDO MODELO PULL (MAKE-TO-ORDER)
# Cliente solicita 200 unidades del producto 105...
#    Stock insuficiente. Faltan 177 unidades.
#    -> PULL ACTIVADO: Comprando 177 unidades urgentemente...
#     Pedido entregado al cliente (Just-in-Time).
#
# 📊 ESTADO FINAL DEL INVENTARIO (ERP INTEGRADO)
#       id                                   nombre   precio  stock_actual  \
# 0    100        Laptop Gamer Muestra (Bajo Stock)  1500.00            25
# 1    101           Cable HDMI Básico (Stock Alto)    15.00           199
# 2    102  Audífonos Noise Cancelling Lenovo Gamer   306.71            88
# 3    103            Mouse Inalámbrico Xiaomi Slim    90.75            86
# 4    104                  Lavadora Apple Business   585.53            23
# ..   ...                                      ...      ...           ...
# 297  397                    Smartphone Lenovo Pro  1325.42            80
# 298  398            Parlante Bluetooth Xiaomi Pro   139.87            71
# 299  399                            Laptop HP Max  1927.56            71
# 300  400                            Laptop LG Pro  1284.85            48
# 301  401                        Monitor Canon Max   178.38            80
#
#      punto_reorden  pronostico_venta
# 0               10                25
# 1               20                50
# 2               26                88
# 3               23                86
# 4               26                23
# ..             ...               ...
# 297             22                80
# 298             30                71
# 299             26                68
# 300             18                48
# 301              5                80
#
# [302 rows x 6 columns]
